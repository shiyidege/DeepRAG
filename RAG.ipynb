# %%
import os

# Install unrar if it's not already installed
if not os.path.exists('/usr/bin/unrar'):
  # !apt-get update && apt-get install -y unrar

# Extract the rar file
# !unrar x /content/rag_project.rar /content/

# Change to the extracted directory
# %cd /content/rag_project
# Out:
# UNRAR 6.11 beta 1 freeware      Copyright (c) 1993-2022 Alexander Roshal
#
#
# Extracting from /content/rag_project.rar
#
# Creating    /content/rag_project                                      OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# Creating    /content/rag_project/data                                 OK
# All OK
# /content/rag_project

# %%
# !pip install -q chromadb sentence-transformers openai tiktoken rank-bm25 matplotlib scikit-learn requests

# 验证安装
import chromadb
import sentence_transformers
from openai import OpenAI
print("✅ 依赖安装完成")
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.0/52.0 kB 2.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.3/23.3 MB 52.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 278.2/278.2 kB 14.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.6/4.6 MB 81.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.7/18.7 MB 66.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.5/72.5 kB 5.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.9/178.9 kB 11.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.9/61.9 kB 3.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 203.7/203.7 kB 13.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.6/71.6 kB 5.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.7/61.7 kB 4.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.6/60.6 kB 3.3 MB/s eta 0:00:00
# ...

# %%
# !python main.py process --max_tokens 512
# Out:
# 06:09:49 [INFO] ==================================================
# 06:09:49 [INFO] 处理数据：分块 + 建索引
# 06:09:49 [INFO] ==================================================
# 06:09:49 [INFO] 已加载 7 篇文章
# 06:09:49 [INFO] 加载 7 篇文章
# 06:09:50 [INFO] 分块完成: 7 篇 → 79 块
# 06:09:50 [INFO] 分块完成: 79 块
# 06:09:59 [INFO] NumExpr defaulting to 2 threads.
# 06:10:02 [INFO] TensorFlow version 2.20.0 available.
# 06:10:02 [INFO] JAX version 0.7.2 available.
# 06:10:07 [INFO] HTTP Request: HEAD https://huggingface.co/BAAI/bge-small-zh-v1.5/resolve/main/modules.json "HTTP/1.1 307 Temporary Redirect"
# ...
# 06:10:07 [WARNING] Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# 06:10:07 [INFO] HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/BAAI/bge-small-zh-v1.5/7999e1d3359715c523056ef9478215996d62a620/modules.json "HTTP/1.1 200 OK"
# ...

# %%
# %cd /content/rag_project
# !python main.py pipeline --max_articles 30 --max_tokens 512 --n_questions 20 --n_eval 10
# Out:
# /content/rag_project
# 06:01:12 [INFO] ============================================================
# 06:01:12 [INFO] 完整 RAG 流水线
# 06:01:12 [INFO] ============================================================
# 06:01:12 [INFO] ==================================================
# 06:01:12 [INFO] 开始爬取维基百科数据
# 06:01:12 [INFO] ==================================================
# 06:01:12 [INFO] 第一阶段：搜索文章标题...
# 06:01:12 [WARNING] 请求失败: 403 Client Error: Too many requests. Please respect our robot policy https://w.wiki/4wJS. (dd12474) for url: https://zh.wikipedia.org/w/api.php?action=query&list=search&srsearch=%E4%BA%BA%E5%B7%A5%E6%99%BA%E8%83%BD&srlimit=10&format=json&srprop=
# 06:01:15 [WARNING] 请求失败: 403 Client Error: Too many requests. Please respect our robot policy https://w.wiki/4wJS. (dd12474) for url: https://zh.wikipedia.org/w/api.php?action=query&list=search&srsearch=%E6%9C%BA%E5%99%A8%E5%AD%A6%E4%B9%A0&srlimit=10&format=json&srprop=
# ...

# %%
# !python main.py eval --n_questions 20 --n_eval 10
# Out:
# 06:12:45 [INFO] ==================================================
# 06:12:45 [INFO] RAG 系统评估
# 06:12:45 [INFO] ==================================================
# 06:12:45 [INFO] 已加载 7 篇文章
# 06:12:46 [INFO] 分块完成: 7 篇 → 79 块
# 06:12:52 [INFO] NumExpr defaulting to 2 threads.
# 06:12:56 [INFO] TensorFlow version 2.20.0 available.
# 06:12:56 [INFO] JAX version 0.7.2 available.
# 06:13:02 [INFO] HTTP Request: HEAD https://huggingface.co/BAAI/bge-small-zh-v1.5/resolve/main/modules.json "HTTP/1.1 307 Temporary Redirect"
# ...
# 06:13:02 [WARNING] Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# 06:13:02 [INFO] HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/BAAI/bge-small-zh-v1.5/7999e1d3359715c523056ef9478215996d62a620/modules.json "HTTP/1.1 200 OK"
# ...

# %%
# %cd /content/rag_project
from IPython.display import Image, display
display(Image(filename="output/eval_results.png"))
# Out:
# /content/rag_project

# %%
# %cd /content/rag_project

# 实验1：小分块
# !python main.py eval --max_tokens 256 --n_questions 15 --n_eval 8

# 实验2：大分块
# !python main.py eval --max_tokens 1024 --n_questions 15 --n_eval 8
# Out:
# /content/rag_project
# 06:15:48 [INFO] ==================================================
# 06:15:48 [INFO] RAG 系统评估
# 06:15:48 [INFO] ==================================================
# 06:15:48 [INFO] 已加载 7 篇文章
# 06:15:49 [INFO] 分块完成: 7 篇 → 146 块
# 06:15:54 [INFO] NumExpr defaulting to 2 threads.
# 06:15:58 [INFO] TensorFlow version 2.20.0 available.
# 06:15:58 [INFO] JAX version 0.7.2 available.
# 06:16:04 [INFO] HTTP Request: HEAD https://huggingface.co/BAAI/bge-small-zh-v1.5/resolve/main/modules.json "HTTP/1.1 307 Temporary Redirect"
# ...
# 06:16:04 [WARNING] Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# 06:16:04 [INFO] HTTP Request: HEAD https://huggingface.co/api/resolve-cache/models/BAAI/bge-small-zh-v1.5/7999e1d3359715c523056ef9478215996d62a620/modules.json "HTTP/1.1 200 OK"
# ...
